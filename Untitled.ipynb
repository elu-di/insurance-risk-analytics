# %% [markdown]
# # Exploratory Data Analysis: AlphaCare Insurance Solutions
#
# **Date:** May 2026
# **Data Period:** Feb 2014 - Aug 2015
# **Purpose:** Understand insurance claims data, identify risk patterns

# %%
# Import libraries
import sys
sys.path.append('..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.data_loader import InsuranceDataLoader
from src.eda_utils import InsuranceEDA

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

print("Libraries loaded successfully!")
# Out:
# Libraries loaded successfully!

# %%
# Load and clean data
loader = InsuranceDataLoader('../data/insurance_data.csv')
df_raw = loader.load_data()
df = loader.clean_data(df_raw)

print(f"Data shape: {df.shape}")
print(f"Columns: {list(df.columns)[:10]}...")
# Out:
# INFO:src.data_loader:Loading data from ..\data\insurance_data.csv
# ERROR:src.data_loader:Data file not found at ..\data\insurance_data.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Load and clean data
#       2 loader = InsuranceDataLoader('../data/insurance_data.csv')
# ----> 3 df_raw = loader.load_data()
#       4 df = loader.clean_data(df_raw)
#       5
#       6 print(f"Data shape: {df.shape}")
#
# File ~\Documents\insurance-risk-analytics\src\data_loader.py:35, in InsuranceDataLoader.load_data(self)
#      33 try:
#      34     logger.info(f"Loading data from {self.data_path}")
# ---> 35     self.data = pd.read_csv(self.data_path)
#      36     logger.info(f"Loaded {len(self.data)} records with {len(self.data.columns)} columns")
#      37     return self.data
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '..\\data\\insurance_data.csv'

# %%
# Initialize EDA class
eda = InsuranceEDA(df)

# Calculate portfolio metrics
metrics = eda.calculate_portfolio_metrics()

print("="*50)
print("PORTFOLIO OVERALL METRICS")
print("="*50)
print(f"Total Premium: R{metrics['total_premium']:,.2f}")
print(f"Total Claims: R{metrics['total_claims']:,.2f}")
print(f"Overall Loss Ratio: {metrics['overall_loss_ratio']:.4f} ({metrics['overall_loss_ratio']*100:.2f}%)")
print(f"Average Margin per Policy: R{metrics['avg_margin']:,.2f}")
print(f"Total Policies: {metrics['total_policies']:,}")
print(f"Claim Frequency: {metrics['claim_frequency']:.2%}")

# %%
# Loss ratio by Province
print("\nLOSS RATIO BY PROVINCE")
loss_by_province = eda.plot_loss_ratio_by_category('Province')
print(loss_by_province)

# %%
# Loss ratio by Gender
print("\nLOSS RATIO BY GENDER")
loss_by_gender = eda.plot_loss_ratio_by_category('Gender')
print(loss_by_gender)

# %%
# Premium vs Claims scatter plot
eda.plot_premium_vs_claims_scatter()

# %%
# Outlier detection for TotalClaims
print("Outlier Analysis - TotalClaims")
outliers_claims = eda.detect_outliers('TotalClaims')

# %%
# Temporal trends
print("Temporal Trends Analysis")
monthly_trends = eda.plot_temporal_trends()
